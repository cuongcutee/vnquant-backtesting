# %%
from core.event import MarketEvent, SignalEvent, OrderEvent, FillEvent, EventType
from datetime import time,date

# %%
m = MarketEvent(symbol = "VCB", date = date(2024,2,1),close = 85000)
n = MarketEvent(symbol = "VCB", date = date(2024,2,1),close = 86000)
o = OrderEvent(symbol='VCB', direction='BUY', quantity=100)
print(m)
print(n)
print(o)
print('type tự động:', m.type)
print('✅ event.py OK')
# Out:
# MarketEvent(type=<EventType.MARKET: 'MARKET'>, symbol='VCB', date=datetime.date(2024, 2, 1), open=0.0, high=0.0, low=0.0, close=85000, volume=0)
# MarketEvent(type=<EventType.MARKET: 'MARKET'>, symbol='VCB', date=datetime.date(2024, 2, 1), open=0.0, high=0.0, low=0.0, close=86000, volume=0)
# OrderEvent(type=<EventType.ORDER: 'ORDER'>, symbol='VCB', direction='BUY', quantity=100, order_type='MARKET')
# type tự động: EventType.MARKET
# ✅ event.py OK

# %%
print(m==n)
# Out:
# True
